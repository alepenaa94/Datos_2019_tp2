# %% [markdown]
# # Limpieza Installs

# %% [markdown]
# En este notebook se busca realizar una limpieza de información del archivo installs.csv, buscamos que los tipos de las columnas sean correctos y ocupen el menor espacio posible, y se analiza que datos son o no relevantes.

# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# A la hora de leer los datos del csv, especificamos el tipo de dato de las columnas con el parámetro dtype y parseamos las columnas cuya información son fechas con el parámetro parse (habiendo visto previamente el csv para identificar los datos de cada columna). Así, se reduce el tiempo de lectura del csv y el espacio de memoria que ocupan los datos.

# %%
installs = pd.read_csv('../Data/installs.csv.gzip', compression = 'gzip', 
                       dtype={'ref_type':'category','application_id':np.int8, 'device_countrycode':'category'}, parse_dates=['created'])

# %%
installs.head()
# Out:
#                   created  application_id             ref_type  \
# 0 2019-03-13 01:43:33.445               0  1891515180541284343
# 1 2019-03-13 04:58:35.078               0  1891515180541284343
# 2 2019-03-13 04:20:57.666               0  1891515180541284343
# 3 2019-03-13 04:20:57.698               0  1891515180541284343
# 4 2019-03-10 22:24:56.684               0  1891515180541284343
#
#               ref_hash  click_hash  attributed  implicit   device_countrycode  \
# 0  8464844987297247076         NaN       False     False  6333597102633388268
# 1  3250564871270161533         NaN       False     False  6333597102633388268
# 2  7953318831018100268         NaN       False      True  6333597102633388268
# 3  7953318831018100268         NaN       False     False  6333597102633388268
# 4  8355110941557237501         NaN       False      True  6333597102633388268
#
#    device_brand  device_model                 session_user_agent user_agent  \
# 0  3.083059e+17  4.445252e+18                                NaN        NaN
# 1  3.083059e+17  4.445252e+18                                NaN        NaN
# 2  5.137992e+17  6.026543e+18  HasOffers Mobile AppTracking v1.0        NaN
# 3  5.137992e+17  6.026543e+18                                NaN        NaN
# 4  1.083369e+18  7.876612e+18  HasOffers Mobile AppTracking v1.0        NaN
#
#                              event_uuid  kind wifi trans_id  \
# 0                                   NaN   NaN  NaN      NaN
# 1                                   NaN   NaN  NaN      NaN
# 2  0bfa9b4c-e07a-4522-b32d-138e3165ac98  Open  NaN      NaN
# 3                                   NaN   NaN  NaN      NaN
# 4  8f235a8c-41bf-4399-b33d-c41577c949b0  Open  NaN      NaN
#
#             ip_address  device_language
# 0  5529284367937637301              NaN
# 1  6098022721363533304              NaN
# 2  4636407223847323867     3.301378e+18
# 3  4636407223847323867              NaN
# 4   685400811232710215     3.301378e+18

# %%
installs.describe(include='all')
# Out:
#                            created  application_id      ref_type  \
# count                         3412     3412.000000  3.412000e+03
# unique                        3412             NaN           NaN
# top     2019-03-09 04:34:41.291000             NaN           NaN
# freq                             1             NaN           NaN
# first   2019-03-05 00:00:38.219000             NaN           NaN
# last    2019-03-13 23:54:00.526000             NaN           NaN
# mean                           NaN       10.247655  1.736533e+18
# std                            NaN        6.016194  1.936976e+17
# min                            NaN        0.000000  1.494519e+18
# 25%                            NaN        7.000000  1.494519e+18
# 50%                            NaN        9.000000  1.891515e+18
# 75%                            NaN       10.000000  1.891515e+18
# max                            NaN       36.000000  1.891515e+18
#
#             ref_hash  click_hash attributed implicit   device_countrycode  \
# count   3.412000e+03         0.0       3412     3412                 3412
# unique           NaN         NaN          1        2                    2
# top              NaN         NaN      False    False  6333597102633388268
# freq             NaN         NaN       3412     2547                 1820
# first            NaN         NaN        NaN      NaN                  NaN
# last             NaN         NaN        NaN      NaN                  NaN
# mean    4.598202e+18         NaN        NaN      NaN                  NaN
# std     2.663828e+18         NaN        NaN      NaN                  NaN
# min     4.958527e+15         NaN        NaN      NaN                  NaN
# 25%     2.268353e+18         NaN        NaN      NaN                  NaN
# 50%     4.603807e+18         NaN        NaN      NaN                  NaN
# 75%     6.912404e+18         NaN        NaN      NaN                  NaN
# max     9.218934e+18         NaN        NaN      NaN                  NaN
#
#         device_brand  device_model session_user_agent  \
# count   1.047000e+03  3.411000e+03               3364
# unique           NaN           NaN                 12
# top              NaN           NaN       http-kit/2.0
# freq             NaN           NaN               1729
# first            NaN           NaN                NaN
# last             NaN           NaN                NaN
# mean    1.877864e+18  4.245276e+18                NaN
# std     1.886461e+18  2.620844e+18                NaN
# min     3.083059e+17  5.112505e+16                NaN
# 25%     3.083059e+17  2.331947e+18                NaN
# 50%     2.208835e+18  2.983638e+18                NaN
# 75%     2.523246e+18  6.882415e+18                NaN
# max     9.169527e+18  9.222450e+18                NaN
#
#                                               user_agent  \
# count                                               1729
# unique                                               334
# top     MercadoPago/2.58.0.2 CFNetwork/976 Darwin/18.2.0
# freq                                                 393
# first                                                NaN
# last                                                 NaN
# mean                                                 NaN
# std                                                  NaN
# min                                                  NaN
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                                  NaN
#
#                                   event_uuid           kind  wifi trans_id  \
# count                                    865            865  1729        6
# unique                                   865             20     2        4
# top     12eb440e-6c7d-4eda-81b7-5cd6524588aa  af_app_opened  True   {hash}
# freq                                       1            428  1377        3
# first                                    NaN            NaN   NaN      NaN
# last                                     NaN            NaN   NaN      NaN
# mean                                     NaN            NaN   NaN      NaN
# std                                      NaN            NaN   NaN      NaN
# min                                      NaN            NaN   NaN      NaN
# 25%                                      NaN            NaN   NaN      NaN
# 50%                                      NaN            NaN   NaN      NaN
# 75%                                      NaN            NaN   NaN      NaN
# max                                      NaN            NaN   NaN      NaN
#
#           ip_address  device_language
# count   3.412000e+03     3.378000e+03
# unique           NaN              NaN
# top              NaN              NaN
# freq             NaN              NaN
# first            NaN              NaN
# last             NaN              NaN
# mean    4.562040e+18     4.915828e+18
# std     2.683422e+18     2.477019e+18
# min     7.118754e+15     1.101539e+17
# 25%     2.249197e+18     3.301378e+18
# 50%     4.436113e+18     3.301378e+18
# 75%     7.017564e+18     6.977049e+18
# max     9.221950e+18     9.028383e+18

# %%
installs.shape
# Out:
# (3412, 18)

# %% [markdown]
# Calculamos la cantidad de datos no nula de cada columna.

# %%
(installs.isnull().sum()*(-1)+3412).sort_values()
# Out:
# click_hash               0
# trans_id                 6
# kind                   865
# event_uuid             865
# device_brand          1047
# wifi                  1729
# user_agent            1729
# session_user_agent    3364
# device_language       3378
# device_model          3411
# device_countrycode    3412
# implicit              3412
# attributed            3412
# ref_hash              3412
# ref_type              3412
# application_id        3412
# ip_address            3412
# created               3412
# dtype: int64

# %% [markdown]
# Como podemos ver, todos los valores de la columna "click_hash" son nulos, además solo 6 registros tienen valor no nulo en la columna "trans_id". Como no nos aportan información para el análisis, eliminamos ambas columnas del Dataframe.

# %%
installs.drop(columns=['click_hash','trans_id'], inplace=True)

# %% [markdown]
# Redefinimos la columna wifi en una del tipo categórica para que la información que presenta sea más comprensible.

# %%
installs['wifi'].value_counts()
# Out:
# True     1377
# False     352
# Name: wifi, dtype: int64

# %%
installs['Wifi_cat'] = ''

# %%
installs.loc[installs['wifi'] == 0, 'Wifi_cat'] = 'Sin Wifi'
installs.loc[installs['wifi'] == 1, 'Wifi_cat'] = 'Con Wifi'
installs.loc[installs['wifi'].isnull(), 'Wifi_cat'] = 'Sin Definir'

# %%
installs['Wifi_cat'].value_counts()
# Out:
# Sin Definir    1683
# Con Wifi       1377
# Sin Wifi        352
# Name: Wifi_cat, dtype: int64

# %%
installs['Wifi_cat'] = installs['Wifi_cat'].astype('category')

# %%
installs.drop(columns=['wifi'], inplace=True)

# %% [markdown]
# Agrupamos los valores de la columna "ref_type" con los de "session_user_agent" para poder encontrar cuales son las publicidades de Google y cuales las de Apple.

# %%
installs.groupby(['ref_type','session_user_agent']).count().reset_index()[['ref_type','session_user_agent']]
# Out:
#                ref_type                                 session_user_agent
# 0   1494519392962156891                  HasOffers Mobile AppTracking v1.0
# 1   1494519392962156891  Mozilla/5.0 (iPad; CPU OS 12_1_4 like Mac OS X...
# 2   1494519392962156891  Mozilla/5.0 (iPhone; CPU iPhone OS 11_2_6 like...
# 3   1494519392962156891  Mozilla/5.0 (iPhone; CPU iPhone OS 11_4_1 like...
# 4   1494519392962156891  Mozilla/5.0 (iPhone; CPU iPhone OS 12_1 like M...
# 5   1494519392962156891  Mozilla/5.0 (iPhone; CPU iPhone OS 12_1 like M...
# 6   1494519392962156891  Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_2 like...
# 7   1494519392962156891  Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_2 like...
# 8   1494519392962156891  Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_4 like...
# 9   1494519392962156891                                         adjust.com
# 10  1494519392962156891                                       http-kit/2.0
# 11  1891515180541284343                  HasOffers Mobile AppTracking v1.0
# 12  1891515180541284343  Mozilla/5.0 (Linux; Android 6.0; ALE-L23) Appl...
# 13  1891515180541284343                                         adjust.com
# 14  1891515180541284343                                       http-kit/2.0

# %% [markdown]
# Con los datos obtenidos reemplazamos los hashs por Google o Apple.

# %%
installs['ref_type'].replace({'1891515180541284343':'Google','1494519392962156891':'Apple'}, inplace=True)

# %%
installs['ref_type'] = installs['ref_type'].astype('category')

# %%
installs['ref_type'].value_counts()
# Out:
# Google    2080
# Apple     1332
# Name: ref_type, dtype: int64

# %%
installs.head()
# Out:
#                   created  application_id ref_type             ref_hash  \
# 0 2019-03-13 01:43:33.445               0   Google  8464844987297247076
# 1 2019-03-13 04:58:35.078               0   Google  3250564871270161533
# 2 2019-03-13 04:20:57.666               0   Google  7953318831018100268
# 3 2019-03-13 04:20:57.698               0   Google  7953318831018100268
# 4 2019-03-10 22:24:56.684               0   Google  8355110941557237501
#
#    click_hash  attributed  implicit   device_countrycode  device_brand  \
# 0         NaN       False     False  6333597102633388268  3.083059e+17
# 1         NaN       False     False  6333597102633388268  3.083059e+17
# 2         NaN       False      True  6333597102633388268  5.137992e+17
# 3         NaN       False     False  6333597102633388268  5.137992e+17
# 4         NaN       False      True  6333597102633388268  1.083369e+18
#
#    device_model                 session_user_agent user_agent  \
# 0  4.445252e+18                                NaN        NaN
# 1  4.445252e+18                                NaN        NaN
# 2  6.026543e+18  HasOffers Mobile AppTracking v1.0        NaN
# 3  6.026543e+18                                NaN        NaN
# 4  7.876612e+18  HasOffers Mobile AppTracking v1.0        NaN
#
#                              event_uuid  kind wifi trans_id  \
# 0                                   NaN   NaN  NaN      NaN
# 1                                   NaN   NaN  NaN      NaN
# 2  0bfa9b4c-e07a-4522-b32d-138e3165ac98  Open  NaN      NaN
# 3                                   NaN   NaN  NaN      NaN
# 4  8f235a8c-41bf-4399-b33d-c41577c949b0  Open  NaN      NaN
#
#             ip_address  device_language
# 0  5529284367937637301              NaN
# 1  6098022721363533304              NaN
# 2  4636407223847323867     3.301378e+18
# 3  4636407223847323867              NaN
# 4   685400811232710215     3.301378e+18

# %%
installs.dtypes
# Out:
# created               datetime64[ns]
# application_id                  int8
# ref_type                    category
# ref_hash                       int64
# click_hash                   float64
# attributed                      bool
# implicit                        bool
# device_countrycode          category
# device_brand                 float64
# device_model                 float64
# session_user_agent            object
# user_agent                    object
# event_uuid                    object
# kind                          object
# wifi                          object
# trans_id                      object
# ip_address                     int64
# device_language              float64
# dtype: object
