# %% [markdown]
# # Limpieza Installs

# %% [markdown]
# En este notebook se busca realizar una limpieza de información del archivo installs.csv, buscamos que los tipos de las columnas sean correctos y ocupen el menor espacio posible, y se analiza que datos son o no relevantes.

# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# A la hora de leer los datos del csv, especificamos el tipo de dato de las columnas con el parámetro dtype y parseamos las columnas cuya información son fechas con el parámetro parse (habiendo visto previamente el csv para identificar los datos de cada columna). Así, se reduce el tiempo de lectura del csv y el espacio de memoria que ocupan los datos.

# %%
installs = pd.read_csv('../Data/installs.csv.gzip', compression = 'gzip', 
                       dtype={'ref_type':'category','application_id':np.int8, 'device_countrycode':'category'}, parse_dates=['created'])

# %%
installs.head()
# Out:
#                   created  application_id             ref_type  \
# 0 2019-04-24 06:23:29.495               1  1494519392962156891
# 1 2019-04-24 02:06:01.032               1  1494519392962156891
# 2 2019-04-20 10:15:36.274               1  1494519392962156891
# 3 2019-04-20 21:56:47.151               1  1494519392962156891
# 4 2019-04-20 22:40:41.239               1  1494519392962156891
#
#               ref_hash click_hash  attributed  implicit   device_countrycode  \
# 0  4716708407362582887        NaN       False      True  6287817205707153877
# 1  7143568733100935872        NaN       False     False  6287817205707153877
# 2  5230323462636548010        NaN       False      True  6287817205707153877
# 3  5097163995161606833        NaN       False      True  6287817205707153877
# 4  6328027616411983332        NaN       False     False  6287817205707153877
#
#    device_brand  device_model session_user_agent user_agent  \
# 0           NaN  3.739127e+17         adjust.com        NaN
# 1           NaN  7.805539e+18         adjust.com        NaN
# 2           NaN  8.355496e+18         adjust.com        NaN
# 3           NaN  2.355772e+18         adjust.com        NaN
# 4           NaN  6.156971e+18         adjust.com        NaN
#
#                              event_uuid      kind wifi trans_id  \
# 0  79837499-2f2a-4605-a663-e322f759424f  app_open  NaN      NaN
# 1                                   NaN       NaN  NaN      NaN
# 2  dda99e3c-9c4b-487d-891c-79f0a02cb4a8  app_open  NaN      NaN
# 3  7010c3ce-0fcf-46c6-9be8-374cc0e20af4  app_open  NaN      NaN
# 4                                   NaN       NaN  NaN      NaN
#
#             ip_address  device_language
# 0  4243443387795468703     3.301378e+18
# 1  4724288679627032761     3.301378e+18
# 2  8291809486355890410     4.060930e+18
# 3  4006811922873399949     3.301378e+18
# 4  3386455054590810771     3.301378e+18

# %%
installs.describe(include='all')
# Out:
#                            created  application_id             ref_type  \
# count                       481511   481511.000000               481511
# unique                      480962             NaN                    2
# top     2019-04-20 16:34:38.892000             NaN  1891515180541284343
# freq                             4             NaN               398906
# first   2019-04-18 00:00:01.560000             NaN                  NaN
# last    2019-04-26 23:59:58.788000             NaN                  NaN
# mean                           NaN       29.923584                  NaN
# std                            NaN       72.792831                  NaN
# min                            NaN     -128.000000                  NaN
# 25%                            NaN      -30.000000                  NaN
# 50%                            NaN       36.000000                  NaN
# 75%                            NaN       78.000000                  NaN
# max                            NaN      127.000000                  NaN
#
#             ref_hash                       click_hash attributed implicit  \
# count   4.815110e+05                             1142     481511   481511
# unique           NaN                             1142          2        2
# top              NaN  Dcd6LLZcvDwqV0DL9DcBzxuO49JkJAc      False    False
# freq             NaN                                1     480369   378343
# first            NaN                              NaN        NaN      NaN
# last             NaN                              NaN        NaN      NaN
# mean    4.608270e+18                              NaN        NaN      NaN
# std     2.664215e+18                              NaN        NaN      NaN
# min     4.062141e+13                              NaN        NaN      NaN
# 25%     2.302034e+18                              NaN        NaN      NaN
# 50%     4.605907e+18                              NaN        NaN      NaN
# 75%     6.914484e+18                              NaN        NaN      NaN
# max     9.223366e+18                              NaN        NaN      NaN
#
#          device_countrycode  device_brand  device_model session_user_agent  \
# count                481511  2.764430e+05  4.546190e+05             466672
# unique                    1           NaN           NaN               4537
# top     6287817205707153877           NaN           NaN       http-kit/2.0
# freq                 481511           NaN           NaN             335311
# first                   NaN           NaN           NaN                NaN
# last                    NaN           NaN           NaN                NaN
# mean                    NaN  3.048272e+18  5.100845e+18                NaN
# std                     NaN  2.512359e+18  2.504734e+18                NaN
# min                     NaN  1.892301e+15  7.967346e+14                NaN
# 25%                     NaN  3.083059e+17  3.057402e+18                NaN
# 50%                     NaN  2.208835e+18  5.274185e+18                NaN
# 75%                     NaN  6.115026e+18  6.794880e+18                NaN
# max                     NaN  9.221592e+18  9.223357e+18                NaN
#
#                                              user_agent  \
# count                                            330768
# unique                                            13727
# top     Grability/17420 CFNetwork/978.0.7 Darwin/18.5.0
# freq                                              10809
# first                                               NaN
# last                                                NaN
# mean                                                NaN
# std                                                 NaN
# min                                                 NaN
# 25%                                                 NaN
# 50%                                                 NaN
# 75%                                                 NaN
# max                                                 NaN
#
#                                   event_uuid    kind    wifi trans_id  \
# count                                 103168  103168  294829     8933
# unique                                103083     183       2     4053
# top     b53e3149-2621-4a35-8f7a-f7820555108d    Open    True        0
# freq                                       2   37257  235130     3145
# first                                    NaN     NaN     NaN      NaN
# last                                     NaN     NaN     NaN      NaN
# mean                                     NaN     NaN     NaN      NaN
# std                                      NaN     NaN     NaN      NaN
# min                                      NaN     NaN     NaN      NaN
# 25%                                      NaN     NaN     NaN      NaN
# 50%                                      NaN     NaN     NaN      NaN
# 75%                                      NaN     NaN     NaN      NaN
# max                                      NaN     NaN     NaN      NaN
#
#           ip_address  device_language
# count   4.815110e+05     4.539340e+05
# unique           NaN              NaN
# top              NaN              NaN
# freq             NaN              NaN
# first            NaN              NaN
# last             NaN              NaN
# mean    4.600401e+18     5.801850e+18
# std     2.668897e+18     1.927775e+18
# min     3.311428e+13     6.645612e+16
# 25%     2.285332e+18     3.301378e+18
# 50%     4.582321e+18     6.977049e+18
# 75%     6.906963e+18     6.977049e+18
# max     9.223363e+18     9.210226e+18

# %%
installs.shape
# Out:
# (481511, 18)

# %% [markdown]
# Calculamos la cantidad de datos no nula de cada columna.

# %%
(installs.isnull().sum()*(-1)+481511).sort_values()
# Out:
# click_hash              1142
# trans_id                8933
# kind                  103168
# event_uuid            103168
# device_brand          276443
# wifi                  294829
# user_agent            330768
# device_language       453934
# device_model          454619
# session_user_agent    466672
# ip_address            481511
# implicit              481511
# attributed            481511
# ref_hash              481511
# ref_type              481511
# application_id        481511
# device_countrycode    481511
# created               481511
# dtype: int64

# %% [markdown]
# Como podemos ver, muy pocos valores de la columnas "click_hash" y "trans_id" tienen valor no nulo. Como no nos aportan mucha información para el análisis, eliminamos ambas columnas del Dataframe.

# %%
installs.drop(columns=['click_hash','trans_id'], inplace=True)

# %% [markdown]
# Redefinimos la columna wifi en una del tipo categórica para que la información que presenta sea más comprensible.

# %%
installs['wifi'].value_counts()
# Out:
# True     235130
# False     59699
# Name: wifi, dtype: int64

# %%
installs['Wifi_cat'] = ''

# %%
installs.loc[installs['wifi'] == 0, 'Wifi_cat'] = 'Sin Wifi'
installs.loc[installs['wifi'] == 1, 'Wifi_cat'] = 'Con Wifi'
installs.loc[installs['wifi'].isnull(), 'Wifi_cat'] = 'Sin Definir'

# %%
installs['Wifi_cat'].value_counts()
# Out:
# Con Wifi       235130
# Sin Definir    186682
# Sin Wifi        59699
# Name: Wifi_cat, dtype: int64

# %%
installs['Wifi_cat'] = installs['Wifi_cat'].astype('category')

# %%
installs.drop(columns=['wifi'], inplace=True)

# %% [markdown]
# Agrupamos los valores de la columna "ref_type" con los de "session_user_agent" para poder encontrar cuales son las publicidades de Google y cuales las de Apple.

# %%
installs.groupby(['ref_type','session_user_agent']).count().reset_index()[['ref_type','session_user_agent']]
# Out:
#                ref_type                                 session_user_agent
# 0   1494519392962156891                  HasOffers Mobile AppTracking v1.0
# 1   1494519392962156891  Mozilla/5.0 (iPad; CPU OS 12_1_4 like Mac OS X...
# 2   1494519392962156891  Mozilla/5.0 (iPhone; CPU iPhone OS 11_2_6 like...
# 3   1494519392962156891  Mozilla/5.0 (iPhone; CPU iPhone OS 11_4_1 like...
# 4   1494519392962156891  Mozilla/5.0 (iPhone; CPU iPhone OS 12_1 like M...
# 5   1494519392962156891  Mozilla/5.0 (iPhone; CPU iPhone OS 12_1 like M...
# 6   1494519392962156891  Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_2 like...
# 7   1494519392962156891  Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_2 like...
# 8   1494519392962156891  Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_4 like...
# 9   1494519392962156891                                         adjust.com
# 10  1494519392962156891                                       http-kit/2.0
# 11  1891515180541284343                  HasOffers Mobile AppTracking v1.0
# 12  1891515180541284343  Mozilla/5.0 (Linux; Android 6.0; ALE-L23) Appl...
# 13  1891515180541284343                                         adjust.com
# 14  1891515180541284343                                       http-kit/2.0

# %% [markdown]
# Con los datos obtenidos reemplazamos los hashs por Google o Apple.

# %%
installs['ref_type'].replace({'1891515180541284343':'Google','1494519392962156891':'Apple'}, inplace=True)

# %%
installs['ref_type'] = installs['ref_type'].astype('category')

# %%
installs['ref_type'].value_counts()
# Out:
# Google    398906
# Apple      82605
# Name: ref_type, dtype: int64

# %%
installs.head()
# Out:
#                   created  application_id ref_type             ref_hash  \
# 0 2019-04-24 06:23:29.495               1    Apple  4716708407362582887
# 1 2019-04-24 02:06:01.032               1    Apple  7143568733100935872
# 2 2019-04-20 10:15:36.274               1    Apple  5230323462636548010
# 3 2019-04-20 21:56:47.151               1    Apple  5097163995161606833
# 4 2019-04-20 22:40:41.239               1    Apple  6328027616411983332
#
#    attributed  implicit   device_countrycode  device_brand  device_model  \
# 0       False      True  6287817205707153877           NaN  3.739127e+17
# 1       False     False  6287817205707153877           NaN  7.805539e+18
# 2       False      True  6287817205707153877           NaN  8.355496e+18
# 3       False      True  6287817205707153877           NaN  2.355772e+18
# 4       False     False  6287817205707153877           NaN  6.156971e+18
#
#   session_user_agent user_agent                            event_uuid  \
# 0         adjust.com        NaN  79837499-2f2a-4605-a663-e322f759424f
# 1         adjust.com        NaN                                   NaN
# 2         adjust.com        NaN  dda99e3c-9c4b-487d-891c-79f0a02cb4a8
# 3         adjust.com        NaN  7010c3ce-0fcf-46c6-9be8-374cc0e20af4
# 4         adjust.com        NaN                                   NaN
#
#        kind           ip_address  device_language     Wifi_cat
# 0  app_open  4243443387795468703     3.301378e+18  Sin Definir
# 1       NaN  4724288679627032761     3.301378e+18  Sin Definir
# 2  app_open  8291809486355890410     4.060930e+18  Sin Definir
# 3  app_open  4006811922873399949     3.301378e+18  Sin Definir
# 4       NaN  3386455054590810771     3.301378e+18  Sin Definir

# %%
installs.dtypes
# Out:
# created               datetime64[ns]
# application_id                  int8
# ref_type                    category
# ref_hash                       int64
# attributed                      bool
# implicit                        bool
# device_countrycode          category
# device_brand                 float64
# device_model                 float64
# session_user_agent            object
# user_agent                    object
# event_uuid                    object
# kind                          object
# ip_address                     int64
# device_language              float64
# Wifi_cat                    category
# dtype: object
