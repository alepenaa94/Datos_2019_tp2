# %% [markdown]
# # Limpieza Events

# %% [markdown]
# En este notebook se busca realizar una limpieza de información del archivo events.csv, buscamos que los tipos de las columnas sean correctos y ocupen el menor espacio posible, y se analiza que datos son o no relevantes.

# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# A la hora de leer los datos del csv, especificamos el tipo de dato de las columnas con el parámetro dtype y parseamos las columnas cuya información son fechas con el parámetro parse (habiendo visto previamente el csv para identificar los datos de cada columna). Así, se reduce el tiempo de lectura del csv y el espacio de memoria que ocupan los datos.

# %%
events = pd.read_csv('../Data/events.csv.gzip', compression = 'gzip', 
                     dtype={'index':np.int32, 'event_id':np.int16,'ref_type': 'category', 'application_id':np.int16, 
                            'device_countrycode': 'category', 'connection_type':'category'}, parse_dates=['date'])

# %%
events.head()
# Out:
#      index                    date  event_id             ref_type  \
# 0  2130678 2019-04-20 01:42:49.120         0  1891515180541284343
# 1  2130680 2019-04-20 01:42:49.340         1  1891515180541284343
# 2  2130681 2019-04-20 01:42:49.365         1  1891515180541284343
# 3  2130684 2019-04-20 01:42:51.438         2  1891515180541284343
# 4  2130688 2019-04-20 01:42:51.838         1  1891515180541284343
#
#               ref_hash  application_id  attributed   device_countrycode  \
# 0  5857744372586891366             210       False  6287817205707153877
# 1  7642521036780133571             210       False  6287817205707153877
# 2  2548841562898283198             210       False  6287817205707153877
# 3   609402887625919085             210       False  6287817205707153877
# 4  9114651763556439823             210       False  6287817205707153877
#
#    device_os_version  device_brand       ...         trans_id    user_agent  \
# 0                NaN           NaN       ...              NaN  5.046185e+18
# 1                NaN           NaN       ...              NaN           NaN
# 2                NaN           NaN       ...              NaN           NaN
# 3                NaN           NaN       ...              NaN           NaN
# 4                NaN           NaN       ...              NaN           NaN
#
#                              event_uuid carrier          kind device_os  \
# 0  5b506964-5f47-4b28-a8c2-8a92d6c23379     NaN  5.882882e+18       NaN
# 1  f1fb9d15-1a7b-4116-8d3b-c4c403e197e2     NaN  4.017674e+18       NaN
# 2  c85a0b15-a5d7-472e-8116-6bfa3db19687     NaN  4.017674e+18       NaN
# 3  f4aa0a97-2de6-4f22-95c6-1b3150112cb9     NaN  6.168309e+18       NaN
# 4  08e2f7f7-875f-4aa0-b337-b9b87b0d83ea     NaN  4.017674e+18       NaN
#
#     wifi  connection_type           ip_address  device_language
# 0  False              NaN  7544543351571901618     3.301378e+18
# 1  False              NaN  6949523255335024165              NaN
# 2  False              NaN  6428537280982666957              NaN
# 3  False              NaN  7607371352198017145              NaN
# 4  False              NaN  2901772839007473756              NaN
#
# [5 rows x 23 columns]

# %%
events.describe(include='all')
# Out:
#                index                        date      event_id  \
# count   7.744581e+06                     7744581  7.744581e+06
# unique           NaN                     7693028           NaN
# top              NaN  2019-04-24 14:41:30.558000           NaN
# freq             NaN                           4           NaN
# first            NaN  2019-04-18 00:00:00.027000           NaN
# last             NaN  2019-04-26 23:59:59.881000           NaN
# mean    3.432491e+05                         NaN  5.931369e+01
# std     5.495955e+05                         NaN  8.738097e+01
# min     0.000000e+00                         NaN  0.000000e+00
# 25%     4.031500e+04                         NaN  2.000000e+00
# 50%     1.039680e+05                         NaN  1.500000e+01
# 75%     3.060970e+05                         NaN  1.150000e+02
# max     2.619098e+06                         NaN  5.760000e+02
#
#                    ref_type      ref_hash  application_id attributed  \
# count               7744581  7.744581e+06    7.744581e+06    7744581
# unique                    2           NaN             NaN          2
# top     1891515180541284343           NaN             NaN      False
# freq                6421584           NaN             NaN    7714809
# first                   NaN           NaN             NaN        NaN
# last                    NaN           NaN             NaN        NaN
# mean                    NaN  4.581569e+18    1.413932e+02        NaN
# std                     NaN  2.658818e+18    7.609497e+01        NaN
# min                     NaN  4.062141e+13    1.000000e+00        NaN
# 25%                     NaN  2.275713e+18    6.800000e+01        NaN
# 50%                     NaN  4.555078e+18    1.220000e+02        NaN
# 75%                     NaN  6.864585e+18    2.100000e+02        NaN
# max                     NaN  9.223366e+18    3.700000e+02        NaN
#
#          device_countrycode  device_os_version  device_brand       ...        \
# count               7744581       2.332975e+06  2.553424e+06       ...
# unique                    1                NaN           NaN       ...
# top     6287817205707153877                NaN           NaN       ...
# freq                7744581                NaN           NaN       ...
# first                   NaN                NaN           NaN       ...
# last                    NaN                NaN           NaN       ...
# mean                    NaN       6.315609e+18  3.072329e+18       ...
# std                     NaN       2.526906e+18  2.469124e+18       ...
# min                     NaN       1.004084e+16  4.359146e+15       ...
# 25%                     NaN       4.821386e+18  3.083059e+17       ...
# 50%                     NaN       7.391844e+18  2.208835e+18       ...
# 75%                     NaN       8.218260e+18  6.115026e+18       ...
# max                     NaN       9.135482e+18  9.221511e+18       ...
#
#         trans_id    user_agent                            event_uuid  \
# count      37642  3.341483e+06                               7714809
# unique     11042           NaN                               7714809
# top            0           NaN  b0ad49ad-00c2-4ed8-9b8a-588016f46742
# freq        7446           NaN                                     1
# first        NaN           NaN                                   NaN
# last         NaN           NaN                                   NaN
# mean         NaN  4.979959e+18                                   NaN
# std          NaN  2.866372e+18                                   NaN
# min          NaN  5.046382e+14                                   NaN
# 25%          NaN  2.527115e+18                                   NaN
# 50%          NaN  4.973035e+18                                   NaN
# 75%          NaN  7.683619e+18                                   NaN
# max          NaN  9.222756e+18                                   NaN
#
#              carrier          kind     device_os     wifi  connection_type  \
# count   1.925901e+06  7.714809e+06  1.870190e+06  7744581          1809296
# unique           NaN           NaN           NaN        2                4
# top              NaN           NaN           NaN    False        Cable/DSL
# freq             NaN           NaN           NaN  5478103          1291512
# first            NaN           NaN           NaN      NaN              NaN
# last             NaN           NaN           NaN      NaN              NaN
# mean    7.041850e+18  5.386691e+18  7.485012e+18      NaN              NaN
# std     2.542362e+18  1.860761e+18  1.591975e+17      NaN              NaN
# min     2.359613e+16  1.621526e+16  6.941825e+18      NaN              NaN
# 25%     6.647944e+18  4.017674e+18  7.531669e+18      NaN              NaN
# 50%     8.707893e+18  5.500848e+18  7.531669e+18      NaN              NaN
# 75%     8.758763e+18  6.123834e+18  7.531669e+18      NaN              NaN
# max     9.220464e+18  9.220024e+18  7.531669e+18      NaN              NaN
#
#           ip_address device_language
# count   7.744581e+06    5.665409e+06
# unique           NaN             NaN
# top              NaN             NaN
# freq             NaN             NaN
# first            NaN             NaN
# last             NaN             NaN
# mean    4.586159e+18    5.347474e+18
# std     2.657233e+18    1.981312e+18
# min     3.311428e+13    6.645612e+16
# 25%     2.278616e+18    3.301378e+18
# 50%     4.566862e+18    6.584214e+18
# 75%     6.866911e+18    6.977049e+18
# max     9.223350e+18    9.210226e+18
#
# [13 rows x 23 columns]

# %%
events.shape
# Out:
# (7744581, 23)

# %% [markdown]
# Calculamos la cantidad de datos no nula de cada columna.

# %%
(events.isnull().sum()*(-1)+7744581).sort_values()
# Out:
# trans_id                37642
# connection_type       1809296
# device_os             1870190
# device_city           1894935
# carrier               1925901
# device_os_version     2332975
# device_brand          2553424
# user_agent            3341483
# device_language       5665409
# device_model          5668092
# session_user_agent    7702301
# event_uuid            7714809
# kind                  7714809
# attributed            7744581
# ip_address            7744581
# application_id        7744581
# ref_hash              7744581
# ref_type              7744581
# event_id              7744581
# wifi                  7744581
# date                  7744581
# device_countrycode    7744581
# index                 7744581
# dtype: int64

# %%
events['device_countrycode'].value_counts()
# Out:
# 6287817205707153877    7744581
# Name: device_countrycode, dtype: int64

# %% [markdown]
# Vemos que "device_countrycode" tiene un único valor.

# %%
events['trans_id'].value_counts()
# Out:
# 0                                                                                                                                              7446
# 3gggAwDzJw5PjvtG5aQp6rsN9kPdqswE_LajCYSD-MLFWk1YAAgxMzQzIDU3OTc3MjNiNTM1YTc4ZGJSODk4NDg2MDJfSkIyMDE5MDQxODAwNDM5NVZOMTlXVVNLTktLTE9HT1YAAAA      36
# {hash}                                                                                                                                           34
# 3gggAwBKYrbPH7pE44CNe2webp2viNkS_LajCbb9j6DCWk1YAC4zOTQyMDAyLTgzM18yMzMxMF85NzY2MzA1Y2IwYTQ1OTQ4YmFmMzAwMDE2M2FmMGEAAAAA                         33
# 58ba31291a73b10bbcca8542                                                                                                                         32
# 58effea4                                                                                                                                         29
# v.2_g.88415_a.6611679423314634635_c.19_t.ua_u.ae002bd04471b299                                                                                   28
# 3gggAwBmV1me1OtBObFxOPVcAiRFiNkS_LajCfjLyJ7FWk1YAC4zOTQyMDAyLTgzM18yMzM4MV85NzU2MDA1Y2I2YzJkNDQ4YmFmMzAwMDEzZTNjNjUAAAAA                         25
# 3gggAwBSWa20NnBDgosy93pnpeV8iNkS_LajCba_sbzBWk1YAC4zOTQyMDAyLTgzM18yMzM0N180MzU0MTA1Y2FmMGJkMjQ4YmFmMzAwMDE5MGQ0NTAAAAAA                         25
# 1904090936a53abfa7c863d2                                                                                                                         25
# v.2_g.88415_a.9b1e66782387d7cffa3488d29d425aa987494368_c.27_t.ua_u.ccf8adaedb28839c                                                               1
# 1904251542a587ae00f4dd4c                                                                                                                          1
# 58bc78fda88a820ffc923221                                                                                                                          1
# 1904251809a53740b6b64ea0                                                                                                                          1
# 3gggAwDX7_SH57RPK5MpU1AecrkTiNkS_LajCbKX99HIWk1YAC4zOTQyMDAyLTgzM18yMzM1OV8zODUxMDA1Y2JkYmExNTQ4YmFmMzAwMDFkOTI1MjQAAAAA                          1
# 3gggAwDOVJdwS4pBqJZmp8s1lxKyiNkS_LajCYKN_sTIWk1YAC4zOTQyMDAyLTgzM18yMzM1OF83MzkxNzA1Y2JkODRjZTQ4YmFmMzAwMDFjMWQzNGIAAAAA                          1
# 58b3a19e                                                                                                                                          1
# 1904080129a5d8b661acc5d2                                                                                                                          1
# 3gggAwB07_CU_OtB2LoUjcLRWNeviNkS_LajCZiBzbfIWk1YAC4zOTQyMDAyLTgzM18yMzM3N18zNDU3OTA1Y2JkNGUzZDQ4YmFmMzAwMDFhNmY1ODcAAAAA                          1
# 1904251715a5cb793e06a30c                                                                                                                          1
# 1904080353a5175875904b11                                                                                                                          1
# 3gggAwC_his56kxO2ppM8CB9kZVJiNkS_LajCbTv-K3JWk1YAC4zOTQxOTAxLTI3M181OTU1Nl84MzU4NDA1Y2JmMzJmODQ4YmFmMzAwMDFlNjBhNDYAAAAA                          1
# 3gggAwBSz3T9Gb5Ejr15PbnqqTpM8NMS_LajCdqrtLnJWk1YACY4NTJfMjAwX3RTY0ZJNURGZXBZMDVjYmY2MWVkNWMzZDhiMDAwMTVmMmMyYh4yMDBfdFNjRkk1REZlcFkAAAA           1
# 1904130027a5873792ab46df                                                                                                                          1
# 3gggAwAOnHhf41lOZL6dMUiETImGiNkS_LajCeLhtOnEWk1YAC4zOTQyMDAyLTgzM18yMzMwOV8xODY0OTA1Y2I1ZTkxYzQ4YmFmMzAwMDFiMTQwMDkAAAAA                          1
# 1903040508a5c483770dd06a                                                                                                                          1
# 1904252033a59993bf1a6f1d                                                                                                                          1
# Name: trans_id, Length: 11042, dtype: int64

# %% [markdown]
# Como de los 7744581 registros que tenemos solo 37642 tienen información en la columna "trans_id", dicha información no nos aporta mucho para el análisis exploratorio. Por lo tanto, decidimos descartar dicha columna

# %%
events.drop(columns='trans_id',inplace=True)

# %% [markdown]
# Redefinimos la columna wifi en una del tipo categórica para que la información que presenta sea más comprensible.

# %%
events['wifi'].value_counts()
# Out:
# False    5478103
# True     2266478
# Name: wifi, dtype: int64

# %%
events['Wifi_cat'] = ''

# %%
events.loc[events['wifi'] == 0, 'Wifi_cat'] = 'Sin Wifi'
events.loc[events['wifi'] == 1, 'Wifi_cat'] = 'Con Wifi'
events.loc[events['wifi'].isnull(), 'Wifi_cat'] = 'Sin Definir'

# %%
events['Wifi_cat'].value_counts()
# Out:
# Sin Wifi    5478103
# Con Wifi    2266478
# Name: Wifi_cat, dtype: int64

# %%
events['Wifi_cat'] = events['Wifi_cat'].astype('category')

# %%
events.drop(columns=['wifi'], inplace=True)

# %% [markdown]
# Con los datos obtenidos de la limpieza de installs reemplazamos los hashs de ref_type por Google o Apple.

# %%
events['ref_type'].replace({'1891515180541284343':'Google','1494519392962156891':'Apple'}, inplace=True)

# %%
events['ref_type'] = events['ref_type'].astype('category')

# %%
events['ref_type'].value_counts()
# Out:
# Google    6421584
# Apple     1322997
# Name: ref_type, dtype: int64

# %%
events.head()
# Out:
#      index                    date  event_id ref_type             ref_hash  \
# 0  2130678 2019-04-20 01:42:49.120         0   Google  5857744372586891366
# 1  2130680 2019-04-20 01:42:49.340         1   Google  7642521036780133571
# 2  2130681 2019-04-20 01:42:49.365         1   Google  2548841562898283198
# 3  2130684 2019-04-20 01:42:51.438         2   Google   609402887625919085
# 4  2130688 2019-04-20 01:42:51.838         1   Google  9114651763556439823
#
#    application_id  attributed   device_countrycode  device_os_version  \
# 0             210       False  6287817205707153877                NaN
# 1             210       False  6287817205707153877                NaN
# 2             210       False  6287817205707153877                NaN
# 3             210       False  6287817205707153877                NaN
# 4             210       False  6287817205707153877                NaN
#
#    device_brand    ...     session_user_agent    user_agent  \
# 0           NaN    ...           3.819516e+18  5.046185e+18
# 1           NaN    ...           3.819516e+18           NaN
# 2           NaN    ...           3.819516e+18           NaN
# 3           NaN    ...           3.819516e+18           NaN
# 4           NaN    ...           3.819516e+18           NaN
#
#                              event_uuid  carrier          kind  device_os  \
# 0  5b506964-5f47-4b28-a8c2-8a92d6c23379      NaN  5.882882e+18        NaN
# 1  f1fb9d15-1a7b-4116-8d3b-c4c403e197e2      NaN  4.017674e+18        NaN
# 2  c85a0b15-a5d7-472e-8116-6bfa3db19687      NaN  4.017674e+18        NaN
# 3  f4aa0a97-2de6-4f22-95c6-1b3150112cb9      NaN  6.168309e+18        NaN
# 4  08e2f7f7-875f-4aa0-b337-b9b87b0d83ea      NaN  4.017674e+18        NaN
#
#    connection_type           ip_address device_language  Wifi_cat
# 0              NaN  7544543351571901618    3.301378e+18  Sin Wifi
# 1              NaN  6949523255335024165             NaN  Sin Wifi
# 2              NaN  6428537280982666957             NaN  Sin Wifi
# 3              NaN  7607371352198017145             NaN  Sin Wifi
# 4              NaN  2901772839007473756             NaN  Sin Wifi
#
# [5 rows x 22 columns]

# %%
events.dtypes
# Out:
# index                          int32
# date                  datetime64[ns]
# event_id                       int16
# ref_type                    category
# ref_hash                       int64
# application_id                 int16
# attributed                      bool
# device_countrycode          category
# device_os_version            float64
# device_brand                 float64
# device_model                 float64
# device_city                  float64
# session_user_agent           float64
# user_agent                   float64
# event_uuid                    object
# carrier                      float64
# kind                         float64
# device_os                    float64
# connection_type             category
# ip_address                     int64
# device_language              float64
# Wifi_cat                    category
# dtype: object
