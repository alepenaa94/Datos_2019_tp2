# %% [markdown]
# # Limpieza Events

# %% [markdown]
# En este notebook se busca realizar una limpieza de información del archivo events.csv, buscamos que los tipos de las columnas sean correctos y ocupen el menor espacio posible, y se analiza que datos son o no relevantes.

# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# A la hora de leer los datos del csv, especificamos el tipo de dato de las columnas con el parámetro dtype y parseamos las columnas cuya información son fechas con el parámetro parse (habiendo visto previamente el csv para identificar los datos de cada columna). Así, se reduce el tiempo de lectura del csv y el espacio de memoria que ocupan los datos.

# %%
events = pd.read_csv('../Data/events.csv.gzip', compression = 'gzip', 
                     dtype={'event_id':np.int16,'ref_type': 'category', 'application_id':np.int16, 
                            'device_countrycode': 'category', 'connection_type':'category'}, parse_dates=['date'])

# %%
events.head()
# Out:
#                      date  event_id             ref_type             ref_hash  \
# 0 2019-03-05 00:09:36.966         0  1891515180541284343  2688759737656491380
# 1 2019-03-05 00:09:38.920         1  1891515180541284343  2688759737656491380
# 2 2019-03-05 00:09:26.195         0  1891515180541284343  2688759737656491380
# 3 2019-03-05 00:09:31.107         2  1891515180541284343  2688759737656491380
# 4 2019-03-09 21:00:36.585         3  1891515180541284343  2635154697734164782
#
#    application_id  attributed   device_countrycode  device_os_version  \
# 0              38       False  6333597102633388268       5.908703e+17
# 1              38       False  6333597102633388268       5.908703e+17
# 2              38       False  6333597102633388268       5.908703e+17
# 3              38       False  6333597102633388268       5.908703e+17
# 4              38       False  6333597102633388268       7.391844e+18
#
#    device_brand  device_model       ...        trans_id  user_agent  \
# 0           NaN  5.990117e+18       ...             NaN         NaN
# 1           NaN  5.990117e+18       ...             NaN         NaN
# 2           NaN  5.990117e+18       ...             NaN         NaN
# 3           NaN  5.990117e+18       ...             NaN         NaN
# 4           NaN  5.960896e+18       ...             NaN         NaN
#
#                              event_uuid       carrier          kind  \
# 0  a9c0b263-acb2-4577-92c5-cbde5d7a5db1  2.248157e+17  5.516623e+18
# 1  1cd98205-0d97-4ec2-a019-667997dbfe7a  2.248157e+17  9.977660e+17
# 2  f02e2924-21ae-492b-b625-9021ae0a4eca  2.248157e+17  5.516623e+18
# 3  a813cf45-a36e-4668-85e2-5395f1564e98  2.248157e+17  8.561153e+18
# 4  63a4f0aa-e147-469f-8c55-4ca4f8d0e310  2.248157e+17  8.731902e+17
#
#       device_os  wifi  connection_type           ip_address device_language
# 0  7.531669e+18   NaN        Cable/DSL  7858558567428669000    4.077062e+17
# 1  7.531669e+18   NaN        Cable/DSL  7858558567428669000    4.077062e+17
# 2  7.531669e+18   NaN        Cable/DSL  7858558567428669000    4.077062e+17
# 3  7.531669e+18   NaN        Cable/DSL  6324037615828123965    4.077062e+17
# 4  7.531669e+18   NaN        Cable/DSL  2894495631302821483    3.301378e+18
#
# [5 rows x 22 columns]

# %%
events.describe(include='all')
# Out:
#                               date      event_id             ref_type  \
# count                      2494423  2.494423e+06              2494423
# unique                     2488829           NaN                    2
# top     2019-03-12 14:36:58.017000           NaN  1891515180541284343
# freq                             3           NaN              1882743
# first   2019-03-05 00:00:00.255000           NaN                  NaN
# last    2019-03-13 23:59:59.984000           NaN                  NaN
# mean                           NaN  9.970445e+01                  NaN
# std                            NaN  1.070903e+02                  NaN
# min                            NaN  0.000000e+00                  NaN
# 25%                            NaN  2.200000e+01                  NaN
# 50%                            NaN  3.100000e+01                  NaN
# 75%                            NaN  1.610000e+02                  NaN
# max                            NaN  7.120000e+02                  NaN
#
#             ref_hash  application_id attributed   device_countrycode  \
# count   2.494423e+06    2.494423e+06    2494423              2494423
# unique           NaN             NaN          2                    1
# top              NaN             NaN      False  6333597102633388268
# freq             NaN             NaN    2489324              2494423
# first            NaN             NaN        NaN                  NaN
# last             NaN             NaN        NaN                  NaN
# mean    4.641486e+18    9.910934e+01        NaN                  NaN
# std     2.660724e+18    5.780986e+01        NaN                  NaN
# min     1.633675e+14    0.000000e+00        NaN                  NaN
# 25%     2.326142e+18    6.300000e+01        NaN                  NaN
# 50%     4.688964e+18    6.600000e+01        NaN                  NaN
# 75%     6.927594e+18    1.450000e+02        NaN                  NaN
# max     9.223316e+18    3.220000e+02        NaN                  NaN
#
#         device_os_version  device_brand  device_model       ...        \
# count        1.022066e+06  1.164963e+06  2.406456e+06       ...
# unique                NaN           NaN           NaN       ...
# top                   NaN           NaN           NaN       ...
# freq                  NaN           NaN           NaN       ...
# first                 NaN           NaN           NaN       ...
# last                  NaN           NaN           NaN       ...
# mean         4.986001e+18  1.633891e+18  4.478847e+18       ...
# std          2.394834e+18  1.626674e+18  2.718014e+18       ...
# min          1.004084e+16  7.949737e+16  9.530216e+14       ...
# 25%          4.353750e+18  3.083059e+17  2.331947e+18       ...
# 50%          4.353750e+18  5.137992e+17  4.430579e+18       ...
# 75%          7.391844e+18  2.987569e+18  6.882415e+18       ...
# max          9.135482e+18  9.178260e+18  9.222450e+18       ...
#
#         trans_id    user_agent                            event_uuid  \
# count         82  1.391527e+06                               2489324
# unique        13           NaN                               2489324
# top       {hash}           NaN  be356e52-ebf2-434c-aba8-ac0634dc0c04
# freq          33           NaN                                     1
# first        NaN           NaN                                   NaN
# last         NaN           NaN                                   NaN
# mean         NaN  4.856492e+18                                   NaN
# std          NaN  2.487552e+18                                   NaN
# min          NaN  5.072532e+15                                   NaN
# 25%          NaN  2.723465e+18                                   NaN
# 50%          NaN  5.022936e+18                                   NaN
# 75%          NaN  6.840860e+18                                   NaN
# max          NaN  9.223277e+18                                   NaN
#
#              carrier          kind     device_os     wifi  connection_type  \
# count   6.164340e+05  2.489324e+06  6.576670e+05  1378872           612463
# unique           NaN           NaN           NaN        2                3
# top              NaN           NaN           NaN     True        Cable/DSL
# freq             NaN           NaN           NaN   930902           331948
# first            NaN           NaN           NaN      NaN              NaN
# last             NaN           NaN           NaN      NaN              NaN
# mean    1.470186e+18  5.364362e+18  7.251101e+18      NaN              NaN
# std     2.575962e+18  2.242979e+18  5.247066e+17      NaN              NaN
# min     2.248157e+17  7.758270e+16  2.748831e+18      NaN              NaN
# 25%     2.248157e+17  4.647949e+18  6.941825e+18      NaN              NaN
# 50%     2.248157e+17  5.500848e+18  7.531669e+18      NaN              NaN
# 75%     1.179587e+18  6.169667e+18  7.531669e+18      NaN              NaN
# max     9.182957e+18  9.215473e+18  7.531669e+18      NaN              NaN
#
#           ip_address device_language
# count   2.494423e+06    2.406604e+06
# unique           NaN             NaN
# top              NaN             NaN
# freq             NaN             NaN
# first            NaN             NaN
# last             NaN             NaN
# mean    4.620786e+18    5.865447e+18
# std     2.672746e+18    2.281192e+18
# min     5.287755e+12    2.025809e+16
# 25%     2.333410e+18    3.301378e+18
# 50%     4.541498e+18    6.804428e+18
# 75%     7.044307e+18    6.977049e+18
# max     9.223367e+18    9.187882e+18
#
# [13 rows x 22 columns]

# %%
events.shape
# Out:
# (2494423, 22)

# %% [markdown]
# Calculamos la cantidad de datos no nula de cada columna.

# %%
(events.isnull().sum()*(-1)+2494423).sort_values()
# Out:
# trans_id                   82
# connection_type        612463
# device_city            614698
# carrier                616434
# device_os              657667
# device_os_version     1022066
# device_brand          1164963
# wifi                  1378872
# user_agent            1391527
# device_model          2406456
# device_language       2406604
# session_user_agent    2482637
# event_uuid            2489324
# kind                  2489324
# device_countrycode    2494423
# attributed            2494423
# application_id        2494423
# ref_hash              2494423
# ref_type              2494423
# event_id              2494423
# ip_address            2494423
# date                  2494423
# dtype: int64

# %%
events['device_countrycode'].value_counts()
# Out:
# 6333597102633388268    2494423
# Name: device_countrycode, dtype: int64

# %% [markdown]
# Vemos que "device_countrycode" tiene un único valor.

# %%
events['trans_id'].value_counts()
# Out:
# {hash}                                                                                                           33
# 0                                                                                                                16
# 103430dcab4b60eb4f                                                                                                9
# 433f38e2c758468ab632dcab7281d4be_Y2NhPTEwLzI1LzIwMTggMTA6Mjk6MjUgUE0mb2ZmZXJJZD0zMzQ1NjQ0NiZhZmZJZD0yMjMyNzUx     7
# 210a4c5786d249c78bb30237abcac890_Y2NhPTQvMjEvMjAxOCA1OjI2OjM3IFBNJm9mZmVySWQ9MzM0NTY0NDYmYWZmSWQ9MTY2MTgxNQ==     6
# 1901171053a509cd7317f2c6                                                                                          2
# 0941bb7b-866f-4d5a-9b85-63e77b27d562                                                                              2
# 77ca31a9-b0e0-4884-8de8-c2ee74f1cc32                                                                              2
# 73f1hsvh52g4soo                                                                                                   1
# 1500439142mb23318419296                                                                                           1
# 57ff03c8                                                                                                          1
# 57d62969                                                                                                          1
# 58ee68fa77874f8785ecbe8cf74e14de_Y2NhPTQvMjUvMjAxOCA5OjI5OjE4IFBNJm9mZmVySWQ9MzM0NTY4ODkmYWZmSWQ9MjIzMzAzOQ==     1
# Name: trans_id, dtype: int64

# %% [markdown]
# Como de los 2494423 registros que tenemos solo 82 tienen información en la columna "trans_id", dicha información no nos aporta mucho para el análisis exploratorio. Por lo tanto, decidimos descartar dicha columna

# %%
events.drop(columns='trans_id',inplace=True)

# %% [markdown]
# Redefinimos la columna wifi en una del tipo categórica para que la información que presenta sea más comprensible.

# %%
events['wifi'].value_counts()
# Out:
# True     930902
# False    447970
# Name: wifi, dtype: int64

# %%
events['Wifi_cat'] = ''

# %%
events.loc[events['wifi'] == 0, 'Wifi_cat'] = 'Sin Wifi'
events.loc[events['wifi'] == 1, 'Wifi_cat'] = 'Con Wifi'
events.loc[events['wifi'].isnull(), 'Wifi_cat'] = 'Sin Definir'

# %%
events['Wifi_cat'].value_counts()
# Out:
# Sin Definir    1115551
# Con Wifi        930902
# Sin Wifi        447970
# Name: Wifi_cat, dtype: int64

# %%
events['Wifi_cat'] = events['Wifi_cat'].astype('category')

# %%
events.drop(columns=['wifi'], inplace=True)

# %% [markdown]
# Con los datos obtenidos de la limpieza de installs reemplazamos los hashs de ref_hash por Google o Apple.

# %%
events['ref_type'].replace({'1891515180541284343':'Google','1494519392962156891':'Apple'}, inplace=True)

# %%
events['ref_type'] = events['ref_type'].astype('category')

# %%
events['ref_type'].value_counts()
# Out:
# Google    1882743
# Apple      611680
# Name: ref_type, dtype: int64

# %%
events.head()
# Out:
#                      date  event_id ref_type             ref_hash  \
# 0 2019-03-05 00:09:36.966         0   Google  2688759737656491380
# 1 2019-03-05 00:09:38.920         1   Google  2688759737656491380
# 2 2019-03-05 00:09:26.195         0   Google  2688759737656491380
# 3 2019-03-05 00:09:31.107         2   Google  2688759737656491380
# 4 2019-03-09 21:00:36.585         3   Google  2635154697734164782
#
#    application_id  attributed   device_countrycode  device_os_version  \
# 0              38       False  6333597102633388268       5.908703e+17
# 1              38       False  6333597102633388268       5.908703e+17
# 2              38       False  6333597102633388268       5.908703e+17
# 3              38       False  6333597102633388268       5.908703e+17
# 4              38       False  6333597102633388268       7.391844e+18
#
#    device_brand  device_model     ...       session_user_agent  user_agent  \
# 0           NaN  5.990117e+18     ...             7.164321e+18         NaN
# 1           NaN  5.990117e+18     ...             7.164321e+18         NaN
# 2           NaN  5.990117e+18     ...             7.164321e+18         NaN
# 3           NaN  5.990117e+18     ...             7.164321e+18         NaN
# 4           NaN  5.960896e+18     ...             7.164321e+18         NaN
#
#                              event_uuid       carrier          kind  \
# 0  a9c0b263-acb2-4577-92c5-cbde5d7a5db1  2.248157e+17  5.516623e+18
# 1  1cd98205-0d97-4ec2-a019-667997dbfe7a  2.248157e+17  9.977660e+17
# 2  f02e2924-21ae-492b-b625-9021ae0a4eca  2.248157e+17  5.516623e+18
# 3  a813cf45-a36e-4668-85e2-5395f1564e98  2.248157e+17  8.561153e+18
# 4  63a4f0aa-e147-469f-8c55-4ca4f8d0e310  2.248157e+17  8.731902e+17
#
#       device_os  connection_type           ip_address  device_language  \
# 0  7.531669e+18        Cable/DSL  7858558567428669000     4.077062e+17
# 1  7.531669e+18        Cable/DSL  7858558567428669000     4.077062e+17
# 2  7.531669e+18        Cable/DSL  7858558567428669000     4.077062e+17
# 3  7.531669e+18        Cable/DSL  6324037615828123965     4.077062e+17
# 4  7.531669e+18        Cable/DSL  2894495631302821483     3.301378e+18
#
#       Wifi_cat
# 0  Sin Definir
# 1  Sin Definir
# 2  Sin Definir
# 3  Sin Definir
# 4  Sin Definir
#
# [5 rows x 21 columns]

# %%
events.dtypes
# Out:
# date                  datetime64[ns]
# event_id                       int16
# ref_type                    category
# ref_hash                       int64
# application_id                 int16
# attributed                      bool
# device_countrycode          category
# device_os_version            float64
# device_brand                 float64
# device_model                 float64
# device_city                  float64
# session_user_agent           float64
# user_agent                   float64
# event_uuid                    object
# carrier                      float64
# kind                         float64
# device_os                    float64
# connection_type             category
# ip_address                     int64
# device_language              float64
# Wifi_cat                    category
# dtype: object
