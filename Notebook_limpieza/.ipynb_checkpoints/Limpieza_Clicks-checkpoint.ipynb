# %% [markdown]
# # Limpieza Clicks

# %% [markdown]
# En este notebook se busca realizar una limpieza de información del archivo clicks.csv, buscamos que los tipos de las columnas sean correctos y ocupen el menor espacio posible, y se analiza que datos son o no relevantes.

# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# A la hora de leer los datos del csv, especificamos el tipo de dato de las columnas con el parámetro dtype y parseamos las columnas cuya información son fechas con el parámetro parse (habiendo visto previamente el csv para identificar los datos de cada columna). Así, se reduce el tiempo de lectura del csv y el espacio de memoria que ocupan los datos.

# %%
clicks = pd.read_csv('../Data/clicks.csv.gzip', compression = 'gzip', 
                     dtype={'ref_type': 'category', 'timeToClick': np.float64, 
                            'specs_brand': 'category', 'country_code': 'category', 'os_minor': np.float32, 'os_major': np.float32, 
                            'agent_device': np.float16, 'advertiser_id': np.int8, 'source_id': np.int8}, parse_dates=['created'])

# %%
clicks['touchX'] = clicks['touchX'].astype('float32')
clicks['touchY'] = clicks['touchY'].astype('float32')

# %%
clicks.head()
# Out:
#    advertiser_id  action_id  source_id                 created  \
# 0              1        NaN          2 2019-04-18 05:27:42.197
# 1              1        NaN          1 2019-04-18 05:27:03.164
# 2              1        NaN          1 2019-04-18 05:42:07.926
# 3              1        NaN          1 2019-04-18 05:26:04.446
# 4              1        NaN          1 2019-04-18 05:23:37.764
#
#           country_code  latitude  longitude  wifi_connection  carrier_id  \
# 0  6287817205707153877  1.714547   0.871535            False         3.0
# 1  6287817205707153877  1.714512   0.871062             True         2.0
# 2  6287817205707153877  1.714547   0.871535             True         4.0
# 3  6287817205707153877  1.708041   0.870772             True         1.0
# 4  6287817205707153877  1.715514   0.870772             True         2.0
#
#                           trans_id      os_minor  agent_device      os_major  \
# 0  9JMAfrb-b9cSEVCJb0P9JfihGthaS7E  1.517644e+18           NaN  5.131615e+18
# 1  r3xtTRv2lInfiXG8JI3NQsNcBo8GyFQ  1.288578e+18           NaN  3.908390e+18
# 2  WOnHFqQtY48z_ygKZ-030U_g0TMGVMw  2.238736e+18           NaN  3.581233e+18
# 3  wQMLLmYqiFhSuha9p9B13PMtcyBW_vM  2.411640e+18           NaN  3.908390e+18
# 4  GeFoyBzMA7taylMxxjzlNPTU-n4FXFs  1.517644e+18           NaN  5.131615e+18
#
#            specs_brand  brand  timeToClick  touchX  touchY  \
# 0    71913840936116953    0.0        2.317   0.968   0.503
# 1  3576558787748411622    1.0        7.653   0.712   1.689
# 2  3576558787748411622    NaN      464.796   0.227   0.251
# 3  3576558787748411622    NaN      225.311   0.696   6.587
# 4  3576558787748411622    0.0       84.736   0.059   0.142
#
#               ref_type             ref_hash
# 0  1891515180541284343  1293710398598742392
# 1  1891515180541284343  1663930990551616564
# 2  1891515180541284343  8488038938665586188
# 3  1891515180541284343  6488361690105189959
# 4  1891515180541284343  1348993302102753419

# %%
clicks.describe(include='all')
# Out:
#         advertiser_id      action_id     source_id  \
# count    64296.000000       7.000000  64296.000000
# unique            NaN            NaN           NaN
# top               NaN            NaN           NaN
# freq              NaN            NaN           NaN
# first             NaN            NaN           NaN
# last              NaN            NaN           NaN
# mean         1.560595  122478.285714      1.251166
# std          0.518691    8510.626039      1.407715
# min          0.000000  103178.000000      0.000000
# 25%          1.000000  125695.000000      0.000000
# 50%          2.000000  125695.000000      1.000000
# 75%          2.000000  125695.000000      1.000000
# max          4.000000  125695.000000      8.000000
#
#                            created         country_code      latitude  \
# count                        64296                64296  64296.000000
# unique                       64275                    1           NaN
# top     2019-04-23 15:15:05.754000  6287817205707153877           NaN
# freq                             2                64296           NaN
# first   2019-04-12 00:00:01.981000                  NaN           NaN
# last    2019-04-26 23:59:22.065000                  NaN           NaN
# mean                           NaN                  NaN      1.740190
# std                            NaN                  NaN      0.045593
# min                            NaN                  NaN      1.660487
# 25%                            NaN                  NaN      1.714512
# 50%                            NaN                  NaN      1.715514
# 75%                            NaN                  NaN      1.744500
# max                            NaN                  NaN      1.885801
#
#            longitude wifi_connection    carrier_id  \
# count   64296.000000           64296  63097.000000
# unique           NaN               2           NaN
# top              NaN            True           NaN
# freq             NaN           40254           NaN
# first            NaN             NaN           NaN
# last             NaN             NaN           NaN
# mean        0.867035             NaN     10.431558
# std         0.017515             NaN     14.161776
# min         0.810223             NaN      0.000000
# 25%         0.863469             NaN      1.000000
# 50%         0.871062             NaN      7.000000
# 75%         0.871535             NaN     13.000000
# max         0.920080             NaN    191.000000
#
#                                trans_id      os_minor  agent_device  \
# count                             64296  6.426100e+04   8920.000000
# unique                            64279           NaN           NaN
# top     jSeHencK5ZYAfQ2azB9GasPmUdM4v6U           NaN           NaN
# freq                                  2           NaN           NaN
# first                               NaN           NaN           NaN
# last                                NaN           NaN           NaN
# mean                                NaN  3.576229e+18           inf
# std                                 NaN  2.320198e+18           NaN
# min                                 NaN  5.106671e+17           inf
# 25%                                 NaN  1.517644e+18           inf
# 50%                                 NaN  2.411640e+18           inf
# 75%                                 NaN  6.795762e+18           inf
# max                                 NaN  8.317279e+18           inf
#
#             os_major        specs_brand         brand   timeToClick  \
# count   6.426100e+04              64296  15035.000000  38178.000000
# unique           NaN                  5           NaN           NaN
# top              NaN  71913840936116953           NaN           NaN
# freq             NaN              35613           NaN           NaN
# first            NaN                NaN           NaN           NaN
# last             NaN                NaN           NaN           NaN
# mean    5.030920e+18                NaN      1.400798    206.954231
# std     1.151353e+18                NaN      1.798718    921.497533
# min     6.900650e+17                NaN      0.000000      0.013000
# 25%     3.908390e+18                NaN      0.000000      2.030250
# 50%     5.131615e+18                NaN      1.000000      8.308500
# 75%     5.648867e+18                NaN      3.000000     56.475250
# max     8.310800e+18                NaN     11.000000  17578.724000
#
#               touchX        touchY             ref_type      ref_hash
# count   4.367800e+04  4.367800e+04                64296  6.429600e+04
# unique           NaN           NaN                    2           NaN
# top              NaN           NaN  1891515180541284343           NaN
# freq             NaN           NaN                60492           NaN
# first            NaN           NaN                  NaN           NaN
# last             NaN           NaN                  NaN           NaN
# mean             inf           inf                  NaN  4.561908e+18
# std              NaN           NaN                  NaN  2.662462e+18
# min     0.000000e+00  0.000000e+00                  NaN  6.936097e+14
# 25%     3.610000e-01  1.050000e-01                  NaN  2.236736e+18
# 50%     6.610000e-01  6.590000e-01                  NaN  4.509922e+18
# 75%     8.920000e-01  9.690000e-01                  NaN  6.867429e+18
# max              inf           inf                  NaN  9.223286e+18

# %%
clicks.dtypes
# Out:
# advertiser_id                int8
# action_id                 float64
# source_id                    int8
# created            datetime64[ns]
# country_code             category
# latitude                  float64
# longitude                 float64
# wifi_connection              bool
# carrier_id                float64
# trans_id                   object
# os_minor                  float32
# agent_device              float16
# os_major                  float32
# specs_brand              category
# brand                     float64
# timeToClick               float64
# touchX                    float32
# touchY                    float32
# ref_type                 category
# ref_hash                    int64
# dtype: object

# %%
clicks['brand'].isnull().sum()
# Out:
# 49261

# %% [markdown]
# Consideramos al valor -1 como nulo, esto es para poder cambiar el tipo de datos de la columna a int8.

# %%
clicks['brand'].fillna(value=-1,inplace=True)

# %%
clicks['brand'] = clicks['brand'].astype('int8')

# %%
clicks['carrier_id'].isnull().sum()
# Out:
# 1199

# %% [markdown]
# Consideramos que el id -1 es que no posee id, esto es para poder cambiar el tipo de datos de la columna a int16.

# %%
clicks['carrier_id'].fillna(value=-1,inplace=True)

# %%
clicks['carrier_id'] = clicks['carrier_id'].astype('int16')

# %%
clicks['action_id'].count()
# Out:
# 7

# %% [markdown]
# Descartamos la columna "action_id" ya que vemos que casi todos sus valores son nulos y por lo tanto la información que nos aporta es mínima.

# %%
clicks.drop(columns='action_id',inplace=True)

# %% [markdown]
# Con los datos obtenidos de la limpieza de installs reemplazamos los hashs de ref_hash por Google o Apple.

# %%
clicks['ref_type'].replace({'1891515180541284343':'Google','1494519392962156891':'Apple'}, inplace=True)

# %%
clicks['ref_type'] = clicks['ref_type'].astype('category')

# %%
clicks['ref_type'].value_counts()
# Out:
# Google    60492
# Apple      3804
# Name: ref_type, dtype: int64

# %%
clicks.head()
# Out:
#    advertiser_id  source_id                 created         country_code  \
# 0              1          2 2019-04-18 05:27:42.197  6287817205707153877
# 1              1          1 2019-04-18 05:27:03.164  6287817205707153877
# 2              1          1 2019-04-18 05:42:07.926  6287817205707153877
# 3              1          1 2019-04-18 05:26:04.446  6287817205707153877
# 4              1          1 2019-04-18 05:23:37.764  6287817205707153877
#
#    latitude  longitude  wifi_connection  carrier_id  \
# 0  1.714547   0.871535            False           3
# 1  1.714512   0.871062             True           2
# 2  1.714547   0.871535             True           4
# 3  1.708041   0.870772             True           1
# 4  1.715514   0.870772             True           2
#
#                           trans_id      os_minor  agent_device      os_major  \
# 0  9JMAfrb-b9cSEVCJb0P9JfihGthaS7E  1.517644e+18           NaN  5.131615e+18
# 1  r3xtTRv2lInfiXG8JI3NQsNcBo8GyFQ  1.288578e+18           NaN  3.908390e+18
# 2  WOnHFqQtY48z_ygKZ-030U_g0TMGVMw  2.238736e+18           NaN  3.581233e+18
# 3  wQMLLmYqiFhSuha9p9B13PMtcyBW_vM  2.411640e+18           NaN  3.908390e+18
# 4  GeFoyBzMA7taylMxxjzlNPTU-n4FXFs  1.517644e+18           NaN  5.131615e+18
#
#            specs_brand  brand  timeToClick  touchX  touchY ref_type  \
# 0    71913840936116953      0        2.317   0.968   0.503   Google
# 1  3576558787748411622      1        7.653   0.712   1.689   Google
# 2  3576558787748411622     -1      464.796   0.227   0.251   Google
# 3  3576558787748411622     -1      225.311   0.696   6.587   Google
# 4  3576558787748411622      0       84.736   0.059   0.142   Google
#
#               ref_hash
# 0  1293710398598742392
# 1  1663930990551616564
# 2  8488038938665586188
# 3  6488361690105189959
# 4  1348993302102753419

# %%
clicks.dtypes
# Out:
# advertiser_id                int8
# source_id                    int8
# created            datetime64[ns]
# country_code             category
# latitude                  float64
# longitude                 float64
# wifi_connection              bool
# carrier_id                  int16
# trans_id                   object
# os_minor                  float32
# agent_device              float16
# os_major                  float32
# specs_brand              category
# brand                        int8
# timeToClick               float64
# touchX                    float32
# touchY                    float32
# ref_type                 category
# ref_hash                    int64
# dtype: object
